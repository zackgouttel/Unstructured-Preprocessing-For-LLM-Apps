# %% [markdown]
# # Preprocessing Unstructured Data for LLM Applications
#
# This notebook contains a full walkthrough on utilizing the Unstructured Open Source Library and the API to preprocess unstructured data (PDFs, Images, PPTs, Emails...) for use in LLM Applications (RAG,CAG, Agentic AI...)
#
# This project was built by **Zakaria Gouttel** while following Matt Robinson & Andrew Ng's ***"Preprocessing Unstructured Data for LLM Applications"*** course on **DeepLearning.ai**

# %% [markdown]
# ## Main Imports
# The cells below include all the main imports utilized in this project

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.display import JSON, display_json

from dotenv import load_dotenv, find_dotenv

import json

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared, operations
from unstructured_client.models.errors import SDKError

from unstructured.partition.html import partition_html
from unstructured.partition.pptx import partition_pptx
from unstructured.staging.base import dict_to_elements, elements_to_json

# %%
_ = load_dotenv(find_dotenv())

import os

DLAI_API_KEY = os.getenv("U_API_KEY")
DLAI_API_URL = os.getenv("U_API_URL")

s = UnstructuredClient(
    api_key_auth=DLAI_API_KEY,
    server_url=DLAI_API_URL,
)

# %% [markdown]
# ## Reading from HTML Files
#
# This section utilizes the partition_html function from Unstructured's open library to read data from HTML files. I've utilized an example from a previous training of mine on HTML. Other examples are available in the repository.

# %%
filename = "example_files/8.4 Web Design Agency Project/MyResult.html"
elements = partition_html(filename=filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Formations\FSI360 Dev Path\LLMs & GenAI Training\preprocessing_unstructured.ipynb Cellule 7 line 2
#       <a href='vscode-notebook-cell:/d%3A/Formations/FSI360%20Dev%20Path/LLMs%20%26%20GenAI%20Training/preprocessing_unstructured.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> filename = "example_files/8.4 Web Design Agency Project/MyResult.html"
# ----> <a href='vscode-notebook-cell:/d%3A/Formations/FSI360%20Dev%20Path/LLMs%20%26%20GenAI%20Training/preprocessing_unstructured.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> elements = partition_html(filename=filename)
#
# NameError: name 'partition_html' is not defined

# %%
element_dict = [el.to_dict() for el in elements]
example_output = json.dumps(element_dict[1:6], indent=2)
print(example_output)

# %%
JSON(example_output)

# %% [markdown]
# ## Reading from PPT Files
#
# This section utilizes the partition_pptx function from the Unstructured open source library to read data from a PowerPoint file.

# %%
import nltk
nltk.download('averaged_perceptron_tagger')

filename = "example_files/msft_openai.pptx"
elements = partition_pptx(filename=filename)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
element_dict = [el.to_dict() for el in elements]
example_output_ppt=json.dumps(element_dict[:], indent=2)
JSON(example_output_ppt).data
# Out:
# [{'type': 'Title',
#   'element_id': '0272e93746a3e4b9d812abd463338715',
#   'text': 'Physical diagram ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '37bb97fc3af881a0c223c1d703e5979c',
#   'text': 'Web Client ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '3ff6b3047ef90bbfb1fa79fd21bfe051',
#   'text': 'User',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '3dd589d9dcfe6f1b278f4eb94cd94979',
#   'text': 'Kingdom of Saudi Arabia',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'd84dbbaf32d4d948633c1f6850d8d8ac',
#   'text': 'Design ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '547b7a2ef6e45c7db4e92aed5ad23791',
#   'text': 'Admin ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '076bd4eeea6b1c28269389fa6696dcc3',
#   'text': 'IDMC Services',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '1702feae3f3e0705433493fa3d869a89',
#   'text': 'Metadata',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '19e99016343596f2e42c7d67e2468519',
#   'text': 'AES Encryption',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': '436d152322fe9ea94f252756e231d25e',
#   'text': '(256 bit)',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '19e99016343596f2e42c7d67e2468519'}},
#  {'type': 'Title',
#   'element_id': '75368d70ec5d97ccb2a85035afc502c8',
#   'text': 'HTTPS One Port: 443 (Outbound) ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '8c151fc2657a4b4a86d0c398f4b3012b',
#   'text': 'Access to Cloud via whitelisted domains and IPs',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '2491d461b1fe5ff8e970dcaddec86a61',
#   'text': 'Metadata',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': '62833a138ab53332bc6768895e7bdb62',
#   'text': '(TLS 1.2)',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '2491d461b1fe5ff8e970dcaddec86a61'}},
#  {'type': 'Title',
#   'element_id': 'f4d97f08fbb62d9cf4887665265504f9',
#   'text': 'Design & Definition Layer',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '1fac6fc82ead3f2d6dfab8987c4bd559',
#   'text': 'Firewall',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '4f877c68b4731e64f13cb77d4cb9b362',
#   'text': 'Firewall',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '8faa42c8411d6129fb4d7719ae66f586',
#   'text': 'Firewall',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '9fc978d72d99e391ae8599ce2d81f25d',
#   'text': 'MC Domain',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '23e6b8d89cc54bb15713802f165a16c4',
#   'text': 'DB Tier(3)',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'c67bd189bbfded6cd54d708a5ba5d76a',
#   'text': 'DMZ Tier(1)',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'a66f7433533aa7872b01c758ec102049',
#   'text': 'Reverse Proxy Server',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '56815a17aaee20214c43f3632990ad2b',
#   'text': 'MC On-Prem Environments',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': 'ce2241161e487b5c3132a9de5003caca',
#   'text': 'Read:\x0b2383',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '56815a17aaee20214c43f3632990ad2b'}},
#  {'type': 'Title',
#   'element_id': '5791cffc03367b2f4a88bf74ebffefb4',
#   'text': 'Power BI / SSAS Development Servers',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': '30f0170f8ac245073e3656fd4434b9c4',
#   'text': 'DWH Node1, IP: 10.50.16.40',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5791cffc03367b2f4a88bf74ebffefb4'}},
#  {'type': 'Title',
#   'element_id': 'd0044f9f9c3573c515ce04e3468813d1',
#   'text': 'Data warehouse Listener\x0bIP: 10.50.16.78',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': '277100e20d90978a2e51a145b554c03d',
#   'text': 'Ports:\x0b51298',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'd0044f9f9c3573c515ce04e3468813d1'}},
#  {'type': 'Title',
#   'element_id': 'd2372f2e0cddd366915f5f79abb2daf2',
#   'text': 'Backend Tier(2)',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'e08e1d4e0ff628bcf843838c3e835dde',
#   'text': 'Secure Agent Group (on-prem)',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': '148b82303e9e378176c8fb012c144b0f',
#   'text': 'DWH Node2, IP: 10.50.16.41',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'e08e1d4e0ff628bcf843838c3e835dde'}},
#  {'type': 'UncategorizedText',
#   'element_id': '09f9282a6b1af5da5b2cd2fd4376160a',
#   'text': 'IP: 10.50.65.31 ',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'e08e1d4e0ff628bcf843838c3e835dde'}},
#  {'type': 'UncategorizedText',
#   'element_id': 'd678414b89a6388dd2b9065c3df49411',
#   'text': '       10.50.65.32',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'e08e1d4e0ff628bcf843838c3e835dde'}},
#  {'type': 'Title',
#   'element_id': '34754dc9226fabb53a63db717fd3afa2',
#   'text': 'Secure Agent Server -1',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': '94bb2e95cad895d03c5fa990dbd8eb60',
#   'text': 'DWH Node DR, IP: 10.200.16.40',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '34754dc9226fabb53a63db717fd3afa2'}},
#  {'type': 'Title',
#   'element_id': 'bfc8736d1dbb23bc51fdd51523322387',
#   'text': 'NLB',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'b29d3d6a9d05f2c9a942d4140b85db66',
#   'text': 'Source/Target Connection e.g. 10g Ethernet ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '3827ef6aa8c901ed8ebe9ccc99f299be',
#   'text': 'Read/Write on Ports: 54321',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '75dab5f5f8bd78a4a8bcd530eab2e767',
#   'text': 'Secure Agent Server -2',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'NarrativeText',
#   'element_id': 'b5ed2d4d0974c57989f55a76ddd876aa',
#   'text': 'Informatica Secure Agents will be managing the physical data',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '75dab5f5f8bd78a4a8bcd530eab2e767'}},
#  {'type': 'Title',
#   'element_id': '55cc918ca0fdfe532fd703b2834f7413',
#   'text': 'workloads execution and connectivity to different sources and targets',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'PageBreak',
#   'element_id': '12bb1538c08ed52a97d373be530821b7',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 1,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '95ac92613a2645b4c5eae06f4d62335d',
#   'text': 'Physical diagram description',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '01b80f2ecfde9afe8573844e0721deda',
#   'text': '1. Top Section –(Google Cloud Platform & IDMC Services)',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '95ac92613a2645b4c5eae06f4d62335d'}},
#  {'type': 'ListItem',
#   'element_id': '44a9e80f226ca93b87f2822429ff71ac',
#   'text': 'Tier: External (Outside the 3-Tier Architecture)',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '01b80f2ecfde9afe8573844e0721deda'}},
#  {'type': 'ListItem',
#   'element_id': 'c2ef5e62d0139b1456362d36e40ba7ae',
#   'text': 'Description: The cloud layer (Google Cloud Platform for hosting Informatica IDMC services) represents the user interface and service layer where data quality (DQ), data governance (DG), data catalog, and integration tasks are defined.',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '01b80f2ecfde9afe8573844e0721deda'}},
#  {'type': 'ListItem',
#   'element_id': '61086a27127648a0d7a19aa31d6f9bb2',
#   'text': 'Main Role: The cloud is used by users to define data quality checks, data governance rules, and data integration tasks. These tasks are orchestrated via the cloud, but the actual execution happens in the on-prem systems.',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '01b80f2ecfde9afe8573844e0721deda'}},
#  {'type': 'ListItem',
#   'element_id': '5a4fb55ff470988d4ec1a2f4ab3c3f1c',
#   'text': 'Key Components:',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '01b80f2ecfde9afe8573844e0721deda'}},
#  {'type': 'ListItem',
#   'element_id': '07a743fccdb4d459be156ac4c218cdde',
#   'text': 'IDMC Services: Allows users to define DQ/DG rules and integration workflows through a web-based interface. These configurations are sent to the on-prem secure agents for execution.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5a4fb55ff470988d4ec1a2f4ab3c3f1c'}},
#  {'type': 'ListItem',
#   'element_id': '4f0fa80105fc5bf90d164fabde306c18',
#   'text': 'Metadata Management: The outcome metadata from the execution of tasks (such as job status, data quality results, error logs) is sent back to the cloud for reporting and analysis.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5a4fb55ff470988d4ec1a2f4ab3c3f1c'}},
#  {'type': 'ListItem',
#   'element_id': '3346eedf97db869c4e5fe63e9ea5b4c3',
#   'text': 'AES Encryption (256-bit): All data managed by Informatica is encrypted using Advanced Encryption Standard (AES) 256-bit encryption for security.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5a4fb55ff470988d4ec1a2f4ab3c3f1c'}},
#  {'type': 'ListItem',
#   'element_id': '3083df8090c0fecc65902f47a74b9a55',
#   'text': 'Secure Connection (Port 443): The connection to the cloud is managed via a secure HTTPS port (443), which uses TLS 1.2 for secure communication. Access to the cloud is restricted to whitelisted domains and IP addresses for added security.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5a4fb55ff470988d4ec1a2f4ab3c3f1c'}},
#  {'type': 'ListItem',
#   'element_id': 'f3e497070a658e6a86652c1f607749cb',
#   'text': 'Data Flow:',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '01b80f2ecfde9afe8573844e0721deda'}},
#  {'type': 'ListItem',
#   'element_id': '331375eb6999272df3692a4ff88ab0d5',
#   'text': 'From Cloud to On-Prem (Proxy server): ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'f3e497070a658e6a86652c1f607749cb'}},
#  {'type': 'ListItem',
#   'element_id': '800518972b55f6a7654a25aed5eb9702',
#   'text': 'Task Definitions: Data integration tasks, data quality checks, and data governance rules are defined in the cloud and sent to the on-prem Secure Agent Group for execution through the proxy server.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '331375eb6999272df3692a4ff88ab0d5'}},
#  {'type': 'ListItem',
#   'element_id': '051a07aea521b17aa7086ae2a6c50403',
#   'text': 'From On-Prem (Proxy server) to Cloud: ',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'f3e497070a658e6a86652c1f607749cb'}},
#  {'type': 'ListItem',
#   'element_id': 'f55025f22013356f35ec0e18aed380a9',
#   'text': 'Outcome Metadata: Once tasks are executed on the on-prem systems (using the on-prem DB data), the results, such as metadata about the job execution, data quality scores, and other status updates, are sent back to the cloud through the proxy server,',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '051a07aea521b17aa7086ae2a6c50403'}},
#  {'type': 'PageBreak',
#   'element_id': 'ef0014897ae4c951da0a02ea8416aa11',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 2,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '0a024aa8e5310ca7f863d13874c99fcf',
#   'text': 'Physical diagram description',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '2cc47a91e2f2bf9da6eb2c016e2a24b5',
#   'text': '2. Middle Section – Secure Agent Group (On-Premises)',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '0a024aa8e5310ca7f863d13874c99fcf'}},
#  {'type': 'ListItem',
#   'element_id': 'e31412c8d6883a8e2e56667bcdeb83f1',
#   'text': 'Tier: DMZ (Presentation Layer) and Backend (Application Layer)',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '2cc47a91e2f2bf9da6eb2c016e2a24b5'}},
#  {'type': 'ListItem',
#   'element_id': 'f06e579c778a43ecd849e8b714a15b1f',
#   'text': 'Description: The Reverse Proxy Server and Secure Agent Group acts as the execution engine within the on-prem environment, processing the tasks defined in the cloud. It securely interfaces with the cloud for task configuration and metadata exchange.',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '2cc47a91e2f2bf9da6eb2c016e2a24b5'}},
#  {'type': 'NarrativeText',
#   'element_id': '1461a809bb1ba502cc8af9e0d8119bfa',
#   'text': 'Firewall Boundary: The diagram indicates that there is a firewall boundary separating the cloud environment from the on-premises infrastructure to control and secure access.',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '2cc47a91e2f2bf9da6eb2c016e2a24b5'}},
#  {'type': 'Title',
#   'element_id': '1a47cc695965c6819a136cdf01a17daa',
#   'text': 'DMZ Role:',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '0a024aa8e5310ca7f863d13874c99fcf'}},
#  {'type': 'NarrativeText',
#   'element_id': 'ba5910b8a68ffaccb49cfec7ddd14e3e',
#   'text': 'Main Role: Reverse Proxy Server is indicated within the DMZ tier, which acts as a gateway between the Cloud and on-prem environments for Secure communication and coordination between the cloud and on-prem environment through a reverse proxy server.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '1a47cc695965c6819a136cdf01a17daa'}},
#  {'type': 'Title',
#   'element_id': 'c54e1db607a9442f2bd23d3d2d417e46',
#   'text': 'Key Tasks:',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '1a47cc695965c6819a136cdf01a17daa'}},
#  {'type': 'NarrativeText',
#   'element_id': '8dde494e51e106769de025f616a89f75',
#   'text': 'Receive Task Configurations: secure coordination and communication. The secure agent receives task definitions (DQ, DG, integration, etc.) from the cloud and initiates their execution on on-prem.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'c54e1db607a9442f2bd23d3d2d417e46'}},
#  {'type': 'NarrativeText',
#   'element_id': '321995cc074b9c8a1b93c96be1a2d639',
#   'text': 'Secure Communication: Ensures secure data exchanges with the cloud environment (task configurations, metadata, and logs).',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'c54e1db607a9442f2bd23d3d2d417e46'}},
#  {'type': 'Title',
#   'element_id': '1d44389373f96622325f6f9932e76c95',
#   'text': 'Data Flow:',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '1a47cc695965c6819a136cdf01a17daa'}},
#  {'type': 'NarrativeText',
#   'element_id': '335747820990780d1cb1da219d11c889',
#   'text': 'From Proxy Server (DMZ) to the Backend: Passes task definitions to the backend secure agent servers for execution.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '1d44389373f96622325f6f9932e76c95'}},
#  {'type': 'Title',
#   'element_id': '96b33940328f0c67c193fa829f53cf65',
#   'text': 'Backend Role:',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '0a024aa8e5310ca7f863d13874c99fcf'}},
#  {'type': 'NarrativeText',
#   'element_id': 'fe6346bfdbd0f5018c30eebe192f8d69',
#   'text': 'Main Role: Executes the tasks defined in the cloud (DQ, DG, integrations) by interacting with the on-prem databases.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '96b33940328f0c67c193fa829f53cf65'}},
#  {'type': 'Title',
#   'element_id': '641526e16cf0d89e243bcd2edba713e6',
#   'text': 'Key Tasks:',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '96b33940328f0c67c193fa829f53cf65'}},
#  {'type': 'NarrativeText',
#   'element_id': '1c6c863664cafac5a846283045f59ced',
#   'text': 'Task Execution: Executes the data integration tasks, data quality checks, and governance rules using the data residing in the on-prem databases.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '641526e16cf0d89e243bcd2edba713e6'}},
#  {'type': 'NarrativeText',
#   'element_id': '32b5ffbcab54aa79648474cca10b1af3',
#   'text': 'Data Quality/Integration: Transforms data as per the rules defined in the cloud (cleaning, validating, integrating).',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '641526e16cf0d89e243bcd2edba713e6'}},
#  {'type': 'NarrativeText',
#   'element_id': '604e915b84f3f9ea231035a3f82beee4',
#   'text': 'Metadata Generation: After the tasks are executed, the secure agents generate outcome metadata (job statuses, data quality scores, logs).',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '641526e16cf0d89e243bcd2edba713e6'}},
#  {'type': 'Title',
#   'element_id': '5fc4294fff38c9a42a9ae3407b228742',
#   'text': 'Data Flow:',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '96b33940328f0c67c193fa829f53cf65'}},
#  {'type': 'NarrativeText',
#   'element_id': '763c7019a92561dcc6435363a414e360',
#   'text': 'From Secure Agent Group (Backend) to Bottom Layer (Execution): interact with the on-prem databases, executing or validating the data tasks as per the task configuration.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5fc4294fff38c9a42a9ae3407b228742'}},
#  {'type': 'NarrativeText',
#   'element_id': 'e5169b48d3911fd97b6f1648fbbaf9c6',
#   'text': 'From Backend to the Proxy Server (DMZ): Passes task outcome to the proxy server to pass it to the cloud.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5fc4294fff38c9a42a9ae3407b228742'}},
#  {'type': 'PageBreak',
#   'element_id': 'f9735d88980c239ed9bff34d5f62d28f',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 3,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '29841eabbd2df41b1f1d127de0230876',
#   'text': 'Physical diagram description',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'ec01e5b134d8d9fba9dcbd4118c16c43',
#   'text': '3. Bottom Section – MC On-Prem Environments (Execution Layer)',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '29841eabbd2df41b1f1d127de0230876'}},
#  {'type': 'ListItem',
#   'element_id': 'b4a90f2d99f1c979458a4f961e2b00d9',
#   'text': 'Tier: Database (DB Layer)',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'ec01e5b134d8d9fba9dcbd4118c16c43'}},
#  {'type': 'ListItem',
#   'element_id': 'c3d25c86967672f5ff3a1779a90b283a',
#   'text': 'Description: This layer stores all data and interacts with the Secure Agent Group during task execution. It serves as the data source and target for tasks but does not perform any execution itself.',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'ec01e5b134d8d9fba9dcbd4118c16c43'}},
#  {'type': 'Title',
#   'element_id': '4b78701cce1c0a89f102413bb3b2e01c',
#   'text': 'Database Role:',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '29841eabbd2df41b1f1d127de0230876'}},
#  {'type': 'NarrativeText',
#   'element_id': '930d582e66dfb84e91c985bd79d509d9',
#   'text': 'Main Role: Stores on-prem data and interacts with the Secure Agent Group to provide data for reading or writing during task execution.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '4b78701cce1c0a89f102413bb3b2e01c'}},
#  {'type': 'Title',
#   'element_id': '5cb2fe03d9b767655b3849f26c04a31e',
#   'text': 'Key Components:',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '4b78701cce1c0a89f102413bb3b2e01c'}},
#  {'type': 'NarrativeText',
#   'element_id': '6007467a4648e8b34d8833f1a67b725c',
#   'text': 'Database Development Servers (High Availability Cluster): Store the operational and transactional data that the Secure Agent Group reads from or writes to during task execution.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5cb2fe03d9b767655b3849f26c04a31e'}},
#  {'type': 'NarrativeText',
#   'element_id': '051052c7558f7affc765d88842ea5ffb',
#   'text': 'Data Warehouse Listener(10.50.16.78): Connects the data warehouse to provide historical or aggregated data for integration or quality checks.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5cb2fe03d9b767655b3849f26c04a31e'}},
#  {'type': 'NarrativeText',
#   'element_id': '9272b41bfd1e36b07f9c54233384f337',
#   'text': 'Power BI/SSAS Development Servers(10.50.65.31 and 10.50.65.32): Use the stored data for reporting, but this layer does not execute tasks defined in the cloud.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5cb2fe03d9b767655b3849f26c04a31e'}},
#  {'type': 'Title',
#   'element_id': 'f5e2277e33bb9f3c6dc545b0a0680927',
#   'text': 'Key Tasks:',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '4b78701cce1c0a89f102413bb3b2e01c'}},
#  {'type': 'NarrativeText',
#   'element_id': 'd3cfd873e806d2d5a8c8fbc0e52003e0',
#   'text': 'Data Storage: Stores both raw data (before task execution) and processed data (after task execution) as needed.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'f5e2277e33bb9f3c6dc545b0a0680927'}},
#  {'type': 'NarrativeText',
#   'element_id': 'd62e8b8d27b417ff98ec95614b492f04',
#   'text': 'Data Querying: Provides data to the Secure Agent Group to read for integration, transformation, or validation tasks.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'f5e2277e33bb9f3c6dc545b0a0680927'}},
#  {'type': 'NarrativeText',
#   'element_id': 'cac3cc92530a98102fc57c26525caf4d',
#   'text': 'Data Writing: Receives modified data from the Secure Agent Group, if tasks require writing back processed data.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'f5e2277e33bb9f3c6dc545b0a0680927'}},
#  {'type': 'Title',
#   'element_id': '65f4f6e19d70a5d33b49dc9f9d5bb050',
#   'text': 'Data Flow:',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '4b78701cce1c0a89f102413bb3b2e01c'}},
#  {'type': 'Title',
#   'element_id': '8349b98b08ff1a5bfe0795d71901b231',
#   'text': 'From Backend (Secure Agent Group) to Database Servers:',
#   'metadata': {'category_depth': 3,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '65f4f6e19d70a5d33b49dc9f9d5bb050'}},
#  {'type': 'NarrativeText',
#   'element_id': '8b27fc294b17acc288a2047d7fe8877a',
#   'text': 'Reads Data on Port 54321: Secure Agent Group reads the necessary data for executing tasks such as ETL, data quality checks, and governance tasks.',
#   'metadata': {'category_depth': 3,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '8349b98b08ff1a5bfe0795d71901b231'}},
#  {'type': 'NarrativeText',
#   'element_id': 'cbc51f74491ad840fa483ae81fcdfd26',
#   'text': 'Writes Data on Port 54321: Secure Agent Group writes back any transformed or processed data if the task involves modifying or integrating new data into the database.',
#   'metadata': {'category_depth': 3,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '8349b98b08ff1a5bfe0795d71901b231'}},
#  {'type': 'Title',
#   'element_id': 'cb7f5247b42faea4fad2960dff5b8bbf',
#   'text': 'Within Bottom Layer (Database to Power BI/SSAS):',
#   'metadata': {'category_depth': 3,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '65f4f6e19d70a5d33b49dc9f9d5bb050'}},
#  {'type': 'NarrativeText',
#   'element_id': '1877692983b0d8651cd158cd6e576a22',
#   'text': 'Provides stored data to the analytics tools (Power BI, SSAS) for reporting and visualization, which is unrelated to the task execution process from the Secure Agent Group.',
#   'metadata': {'category_depth': 3,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'cb7f5247b42faea4fad2960dff5b8bbf'}},
#  {'type': 'PageBreak',
#   'element_id': 'cdfe1f34eb5f30a193a81af0e2a00368',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 4,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'b5d9733bdae1c7d8ff6edbe03133f121',
#   'text': 'Data Flow',
# ...
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 12,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '34de0be19acc88f0cfab1980ae062853'}},
#  {'type': 'Table',
#   'element_id': '8308ae533281621423ad2ca3126d00c6',
#   'text': 'Service Main IP DR IP Informatica IDMC Services 34.1.55.66 34.1.51.130 34.1.51.131 34.215.138.77 34.217.216.210 44.228.239.240 34.1.51.115 34.1.53.38 34.225.222.175 44.215.191.102 174.129.76.131 34.1.49.12 34.1.48.122 34.166.10.209 34.166.73.137 34.1.51.224 34.1.51.74 34.166.50.55 34.166.71.116 34.1.50.222 34.1.55.195 34.1.57.13 34.1.52.77 34.1.48.0/20 34.152.84.0/23 34.166.0.0/16 34.177.48.0/23 34.1.48.0/20 34.152.84.0/23 34.166.0.0/16 34.177.48.0/23',
#   'metadata': {'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 12,
#    'text_as_html': '<table><tr><td>Service</td><td>Main IP</td><td>DR IP</td></tr><tr><td>Informatica IDMC Services</td><td>34.1.55.66 34.1.51.130 34.1.51.131 34.215.138.77 34.217.216.210 44.228.239.240</td><td>34.1.51.115 34.1.53.38 34.225.222.175 44.215.191.102 174.129.76.131</td></tr><tr><td/><td>34.1.49.12</td><td>34.1.48.122</td></tr><tr><td/><td>34.166.10.209</td><td>34.166.73.137</td></tr><tr><td/><td>34.1.51.224</td><td>34.1.51.74</td></tr><tr><td/><td>34.166.50.55</td><td>34.166.71.116</td></tr><tr><td/><td>34.1.50.222</td><td>34.1.55.195</td></tr><tr><td/><td>34.1.57.13</td><td>34.1.52.77</td></tr><tr><td/><td>34.1.48.0/20 34.152.84.0/23 34.166.0.0/16 34.177.48.0/23</td><td>34.1.48.0/20 34.152.84.0/23 34.166.0.0/16 34.177.48.0/23</td></tr></table>',
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '34de0be19acc88f0cfab1980ae062853'}},
#  {'type': 'PageBreak',
#   'element_id': 'e851bf489d75f4c2358ba1f20d7a26a2',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 12,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '5ac48ff11cd276bb759e85cb4418e96e',
#   'text': 'Main Functionality and business needs',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'ListItem',
#   'element_id': '8aa785bab70d95890ce1e706f097e6e2',
#   'text': 'Main Functionality',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'NarrativeText',
#   'element_id': '376ca760c69ad018dceb0a9291af62ff',
#   'text': 'Secure Data Transfer: The Secure Agent acts as a bridge, run the tasks on-prem, facilitating secure metadata transfer between cloud-based IDMC services and on-premises databases through proxy server.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'NarrativeText',
#   'element_id': '8e6088bb453274e8c4b716fba572bd61',
#   'text': 'Local Data Processing: Executes data management workflows locally without moving sensitive data to the cloud, ensuring compliance.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'NarrativeText',
#   'element_id': '445a4c893ff235d0cf83f5aa04a061fa',
#   'text': 'Seamless Integration: Connects to multiple data sources and targets for processing, transformation, and loading.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'NarrativeText',
#   'element_id': '07c536fe93765f95224a68e859488293',
#   'text': 'High Performance & Availability: Operates within a clustered setup to ensure efficient processing and fault tolerance.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'ListItem',
#   'element_id': 'aabf59bda44819cbc85e2d3229ac62f5',
#   'text': 'Business Needs',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'NarrativeText',
#   'element_id': 'db4ddec996820d9c23d4746a4e3e67f0',
#   'text': 'Data Privacy & Security: Maintains secure data transfer, adhering to data privacy policies.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'NarrativeText',
#   'element_id': '4932799694d2bd3101e040f1f5089201',
#   'text': 'Compliance: Processes data on-premises, meeting local data residency and regulatory requirements.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'Title',
#   'element_id': '531be913a67de4919e141201f54a16a9',
#   'text': 'Efficient Workload Execution: Optimizes data management tasks for timely business insights.',
#   'metadata': {'category_depth': 2,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '5ac48ff11cd276bb759e85cb4418e96e'}},
#  {'type': 'UncategorizedText',
#   'element_id': 'bbe8e5853a26ca910516487d64651b85',
#   'text': 'Reliable Data Operations: Provides high availability and redundancy for critical business data processes.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': '531be913a67de4919e141201f54a16a9'}},
#  {'type': 'PageBreak',
#   'element_id': '1aa03a042c09d49f1c49d4fa1e6f7b0b',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 13,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'ccd3435c6854f1921348119b0cd38d6a',
#   'text': 'Required network ports and justification',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 14,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'NarrativeText',
#   'element_id': '5dc914e343e7bbd8c313acece6b6ed1c',
#   'text': 'Details are in the Firewall request\xa0document',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 14,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'ccd3435c6854f1921348119b0cd38d6a'}},
#  {'type': 'Table',
#   'element_id': '647c6b49fc6a2f34d62222b86c4aae02',
#   'text': 'Source Destination Port Justification Type of Connection IDMC Cloud (Informatica) Revers Proxy server(DMZ) 443 Secure communication (task definitions and metadata). Read/Write Reverse Proxy Server (DMZ) Secure Agent Group (Backend) 54320 Securely pass task definitions and configurations Read/Write Secure Agent Group (On-Prem) On-Prem Data Warehouse 54321 Interaction with data warehouse to retrieve historical data for querying or transformation tasks. Read/Write Secure Agent Group (On-Prem) Power BI/SSAS 54322 Interaction with data warehouse to retrieve historical data for querying or transformation tasks. Read/Write Power BI/SSAS On-Prem DWH Servers 2383 Querying the on-prem databases for analytics and reporting purposes. Read Only Secure Agent Group (On-Prem) Secure agent NLB (Load Balancer) 55000 Load balancing between multiple Secure Agent Servers for efficient task distribution. Read/Write DWH Listener DWH Servers 51298 Communication between DWH Listener and Data Warehouse Servers (high availability cluster). Read/Write',
#   'metadata': {'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 14,
#    'text_as_html': '<table><tr><td>Source</td><td>Destination</td><td>Port</td><td>Justification</td><td>Type of Connection</td></tr><tr><td>IDMC Cloud (Informatica)</td><td>Revers Proxy server(DMZ)</td><td>443</td><td>Secure communication (task definitions and metadata).</td><td>Read/Write</td></tr><tr><td>Reverse Proxy Server (DMZ)</td><td>Secure Agent Group (Backend)</td><td>54320</td><td>Securely pass task definitions and configurations</td><td>Read/Write</td></tr><tr><td>Secure Agent Group (On-Prem)</td><td>On-Prem Data Warehouse</td><td>54321</td><td>Interaction with data warehouse to retrieve historical data for querying or transformation tasks.</td><td>Read/Write</td></tr><tr><td>Secure Agent Group (On-Prem)</td><td>Power BI/SSAS</td><td>54322</td><td>Interaction with data warehouse to retrieve historical data for querying or transformation tasks.</td><td>Read/Write</td></tr><tr><td>Power BI/SSAS</td><td>On-Prem DWH Servers</td><td>2383</td><td>Querying the on-prem databases for analytics and reporting purposes.</td><td>Read Only</td></tr><tr><td>Secure Agent Group (On-Prem)</td><td>Secure agent NLB (Load Balancer)</td><td>55000</td><td>Load balancing between multiple Secure Agent Servers for efficient task distribution.</td><td>Read/Write</td></tr><tr><td>DWH Listener</td><td>DWH Servers</td><td>51298</td><td>Communication between DWH Listener and Data Warehouse Servers (high availability cluster).</td><td>Read/Write</td></tr></table>',
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'ccd3435c6854f1921348119b0cd38d6a'}},
#  {'type': 'PageBreak',
#   'element_id': '36eca5da44f51576476d20aa74a20760',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 14,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '419677ce91846c06ed308fd01b32e730',
#   'text': '3-Tier architect',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 15,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'PageBreak',
#   'element_id': '044d0cf3469fba31d203ddee713a7880',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 15,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'NarrativeText',
#   'element_id': 'b4eeff9ee9d6011564b40e0804ee5512',
#   'text': 'As explained in the diagrams, communication between all servers will be through ports 54320, 54321, 54322 and 51298 (5 digits port).',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 16,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': 'e24f868472e6147725cdd1f14cde8310',
#   'text': 'Communication between PBI, SSAS and on-prem DWH servers through port 2383.',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 16,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'UncategorizedText',
#   'element_id': 'e78693acd40893b13bfd4be3a4916108',
#   'text': 'HTTPs port connection: 443, between proxy server on prem and IDMC on cloud.',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 16,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation',
#    'parent_id': 'e24f868472e6147725cdd1f14cde8310'}},
#  {'type': 'PageBreak',
#   'element_id': 'ddbaf5d88d538a2cf0a6ead9f3616539',
#   'text': '',
#   'metadata': {'last_modified': '2024-11-04T13:18:27',
#    'page_number': 16,
#    'languages': ['eng'],
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'NarrativeText',
#   'element_id': '5f0e4a6a3cfc0239896518fc39739e59',
#   'text': 'All users will utilize authenticated accounts to access data (service accounts or otherwise)',
#   'metadata': {'category_depth': 0,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 17,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}},
#  {'type': 'Title',
#   'element_id': '80b328e2f4208454a8784a5a4f2b9e43',
#   'text': 'Authentication: Windows or SQL Server Authentication',
#   'metadata': {'category_depth': 1,
#    'file_directory': 'example_files',
#    'filename': 'example.pptx',
#    'last_modified': '2024-11-04T13:18:27',
#    'page_number': 17,
#    'languages': ['eng'],
#    'filetype': 'application/vnd.openxmlformats-officedocument.presentationml.presentation'}}]

# %% [markdown]
# ## Reading from PDF
#
# This section utilizes the partition_pdf function from the Unstructured open source library to read data from a PDF file.

# %%
filename = "example_files/CoT.pdf"
resp = partition_pdf(
    filename=filename,
    strategy="hi_res",
    extract_images_in_pdf=False,
)
element_dict_pdf = [el.to_dict() for el in resp]

example_output = json.dumps(element_dict_pdf[1:6], indent=2)
print(example_output)
# Out:
# INFO: Reading PDF for file: example_files/CoT.pdf ...
# [
#   {
#     "type": "NarrativeText",
#     "element_id": "055f2fa97fbdee35766495a3452ebd9d",
#     "text": "This section contains tables for experimental results for varying models and model sizes, on all benchmarks, for standard prompting vs. chain-of-thought prompting.",
#     "metadata": {
#       "detection_class_prob": 0.940491259098053,
#       "coordinates": {
#         "points": [
#           [
#             295.1437683105469,
#             271.98025166666656
#           ],
#           [
#             295.1437683105469,
#             329.9569183333334
#           ],
#           [
#             1409.8411865234375,
#             329.9569183333334
#           ],
#           [
#             1409.8411865234375,
#             271.98025166666656
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 1700,
#         "layout_height": 2200
#       },
#       "last_modified": "2025-03-03T14:56:23",
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "parent_id": "826446fa7830f0352c88808f40b0cc9b",
#       "file_directory": "example_files",
#       "filename": "CoT.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9bf5af5255b80aace01b2da84ea86531",
#     "text": "For the arithmetic reasoning benchmarks, some chains of thought (along with the equations produced) were correct, except the model performed an arithmetic operation incorrectly. A similar observation was made in Cobbe et al. (2021). Hence, we can further add a Python program as an external calculator (using the Python eval function) to all the equations in the generated chain of thought. When there are multiple equations in a chain of thought, we propagate the external calculator results from one equation to the following equations via string matching. As shown in Table 1, we see that adding a calculator signi\ufb01cantly boosts performance of chain-of-thought prompting on most tasks.",
#     "metadata": {
#       "detection_class_prob": 0.9474513530731201,
#       "coordinates": {
#         "points": [
#           [
#             298.7,
#             347.80802944444434
#           ],
#           [
#             298.7,
#             557.2985849999999
#           ],
#           [
#             1404.8353126388886,
#             557.2985849999999
#           ],
#           [
#             1404.8353126388886,
#             347.80802944444434
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 1700,
#         "layout_height": 2200
#       },
#       "links": [
#         {
#           "text": "Cobbe et al .",
#           "url": null,
#           "start_index": 212
#         },
#         {
#           "text": "2021",
#           "url": null,
#           "start_index": 226
#         },
#         {
#           "text": "1",
#           "url": null,
#           "start_index": 577
#         }
#       ],
#       "last_modified": "2025-03-03T14:56:23",
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "parent_id": "826446fa7830f0352c88808f40b0cc9b",
#       "file_directory": "example_files",
#       "filename": "CoT.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "46381dc72867b437cb990fc7734840ee",
#     "text": "Table 1: Chain of thought prompting outperforms standard prompting for various large language models on \ufb01ve arithmetic reasoning benchmarks. All metrics are accuracy (%). Ext. calc.: post-hoc external calculator for arithmetic computations only. Prior best numbers are from the following. a: Cobbe et al. (2021). b & e: Pi et al. (2022), c: Lan et al. (2021), d: Pi\u02dbekos et al. (2021).",
#     "metadata": {
#       "detection_class_prob": 0.9191030859947205,
#       "coordinates": {
#         "points": [
#           [
#             297.3265380859375,
#             606.960807222222
#           ],
#           [
#             297.3265380859375,
#             725.5430294444443
#           ],
#           [
#             1407.72900390625,
#             725.5430294444443
#           ],
#           [
#             1407.72900390625,
#             606.960807222222
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 1700,
#         "layout_height": 2200
#       },
#       "links": [
#         {
#           "text": "Cobbe et al .",
#           "url": null,
#           "start_index": 292
#         },
#         {
#           "text": "2021",
#           "url": null,
#           "start_index": 306
#         },
#         {
#           "text": "Pi et al .",
#           "url": null,
#           "start_index": 320
#         },
#         {
#           "text": "2022",
#           "url": null,
#           "start_index": 331
#         },
#         {
#           "text": "Lan et al .",
#           "url": null,
#           "start_index": 341
#         },
#         {
#           "text": "2021",
#           "url": null,
#           "start_index": 353
#         },
#         {
#           "text": "Pi \u02db ekos et al .",
#           "url": null,
#           "start_index": 363
#         },
#         {
#           "text": "2021",
#           "url": null,
#           "start_index": 379
#         }
#       ],
#       "last_modified": "2025-03-03T14:56:23",
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "parent_id": "826446fa7830f0352c88808f40b0cc9b",
#       "file_directory": "example_files",
#       "filename": "CoT.pdf"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "b4e6349b1541473ca5fca86310d58ba4",
#     "text": "Prompting GSM8K SVAMP ASDiv AQuA MAWPS Prior best N/A (\ufb01netuning) 55a 57.4b 75.3c 37.9d 88.4e UL2 20B Standard 4.1 10.1 16.0 20.5 16.6 Chain of thought 4.4 (+0.3) 12.5 (+2.4) 16.9 (+0.9) 23.6 (+3.1) 19.1 (+2.5) + ext. calc 6.9 28.3 34.3 23.6 42.7 LaMDA 137B Standard 6.5 29.5 40.1 25.5 43.2 Chain of thought 14.3 (+7.8) 37.5 (+8.0) 46.6 (+6.5) 20.6 (-4.9) 57.9 (+14.7) + ext. calc 17.8 42.1 53.4 20.6 69.3 GPT-3 175B Standard 15.6 65.7 70.3 24.8 72.7 (text-davinci-002) Chain of thought 46.9 (+31.3) 68.9 (+3.2) 71.3 (+1.0) 35.8 (+11.0) 87.1 (+14.4) + ext. calc 49.6 70.3 71.1 35.8 87.5 Codex Standard 19.7 69.9 74.0 29.5 78.7 (code-davinci-002) Chain of thought 63.1 (+43.4) 76.4 (+6.5) 80.4 (+6.4) 45.3 (+15.8) 92.6 (+13.9) + ext. calc 65.4 77.0 80.0 45.3 93.3 PaLM 540B Standard 17.9 69.4 72.1 25.2 79.2 Chain of thought 56.9 (+39.0) 79.0 (+9.6) 73.9 (+1.8) 35.8 (+10.6) 93.3 (+14.2) + ext. calc 58.6 79.8 72.6 35.8 93.5",
#     "metadata": {
#       "detection_class_prob": 0.9267750382423401,
#       "coordinates": {
#         "points": [
#           [
#             320.5267639160156,
#             731.715087890625
#           ],
#           [
#             320.5267639160156,
#             1387.8294677734375
#           ],
#           [
#             1368.7069091796875,
#             1387.8294677734375
#           ],
#           [
#             1368.7069091796875,
#             731.715087890625
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 1700,
#         "layout_height": 2200
#       },
#       "last_modified": "2025-03-03T14:56:23",
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "parent_id": "826446fa7830f0352c88808f40b0cc9b",
#       "file_directory": "example_files",
#       "filename": "CoT.pdf"
#     }
#   },
#   {
#     "type": "Header",
#     "element_id": "0301f13983c12f215df253d2e16300d0",
#     "text": "20",
#     "metadata": {
#       "detection_class_prob": 0.609601616859436,
#       "coordinates": {
#         "points": [
#           [
#             835.84375,
#             2063.124696111111
#           ],
#           [
#             835.84375,
#             2090.798585
#           ],
#           [
#             865.3739624023438,
#             2090.798585
#           ],
#           [
#             865.3739624023438,
#             2063.124696111111
#           ]
#         ],
#         "system": "PixelSpace",
#         "layout_width": 1700,
#         "layout_height": 2200
#       },
#       "last_modified": "2025-03-03T14:56:23",
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "file_directory": "example_files",
#       "filename": "CoT.pdf"
#     }
#   }
# ]

# %% [markdown]
# ## Metadata Extraction and Chunking
#
# In this section, we will handle Metadata extraction & Chunking using Hybrid Search and Vector DBs

# %% [markdown]
# ### Main Imports

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
from unstructured.chunking.basic import chunk_elements
from unstructured.chunking.title import chunk_by_title
from unstructured.staging.base import dict_to_elements

import chromadb

# %% [markdown]
# ### Example
#
# We will try with the Winter Sport EPUB file in the example files folder, to use this file we need to use the Platform API not the open source library.

# %%
# Prepare the request input.

filename = "./example_files/winter-sports.epub"

with open(filename, "rb") as f:
    files=shared.Files(
        content=f.read(),
        file_name=filename,
    )

params=shared.PartitionParameters(files=files)

req = operations.PartitionRequest(partition_parameters=params)

# %%
# Send the request.

try:
    resp = s.general.partition(request=req)
except SDKError as e:
    print(e)

JSON(json.dumps(resp.elements[0:3], indent=2)).data
# Out:
# [{'type': 'Title',
#   'element_id': 'c2994d1baf27b22f630c8f044664879d',
#   'text': 'The Project Gutenberg eBook of Winter Sports in Switzerland, by E. F. Benson',
#   'metadata': {'category_depth': 1,
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub'}},
#  {'type': 'NarrativeText',
#   'element_id': '5cea770359a3b1342a867bac7831ebcd',
#   'text': 'This ebook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions whatsoever. You may copy it, give it away or re-use it under the terms of the Project Gutenberg License included with this ebook or online at www.gutenberg.org. If you are not located in the United States, you’ll have to check the laws of the country where you are located before using this eBook.',
#   'metadata': {'link_texts': ['www.gutenberg.org'],
#    'link_urls': ['https://www.gutenberg.org'],
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': 'c2994d1baf27b22f630c8f044664879d'}},
#  {'type': 'UncategorizedText',
#   'element_id': '1a59d7811e2572dc8341cc63a8e078ef',
#   'text': 'Title: Winter Sports in Switzerland',
#   'metadata': {'emphasized_text_contents': ['Title'],
#    'emphasized_text_tags': ['b'],
#    'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': 'c2994d1baf27b22f630c8f044664879d'}}]

# %%
#Search for an element within the book which is Narrative Text, and that contains the word hockey.

[x for x in resp.elements if x['type'] == 'NarrativeText' and 'hockey' in x['text'].lower()]
# Out:
# [{'type': 'NarrativeText',
#   'element_id': '80e426d3de10c91ca6ff1b7880f388c8',
#   'text': 'But at every Swiss resort there are rinks made, which render the skater independent of natural surfaces of ice, and those, at all well-conducted places, are “new every morning,” because every evening they are swept and sprinkled with water, which by the ensuing day has frozen, and presents a fresh surface to the zealot. In fact, an artificial skating-rink is as necessary an equipment in the Swiss winter resort as is the hotel itself. The construction and renovation of these rinks is most interesting, and ranks among the fine arts, just as does the architecture of a fine golf-links or the preparation of good wickets. These rinks are used for two purposes: skating, including bandy or ice hockey, and curling. I do not count ice-gymkhanas or ice-carnivals, because anything is good enough for them. You can play the shovel-game or crawl through barrels among the jungles of frost-flowers. I do not imply that such entertainment is not exceedingly amusing; I only mean that the artist in rink-making paints his masterpieces primarily for the sake of the skater and the curler, not for the Pierrot with his Chinese lantern, or those who win three-legged races.',
#   'metadata': {'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': '4e3f02ce1525ca1a197b5d5e9cd1953d'}},
#  {'type': 'NarrativeText',
#   'element_id': '24a39efc765a60db62dd23405133a957',
#   'text': 'Many of the Swiss winter-resorts can put into the field a very strong ice-hockey team, and fine teams from other countries often make winter tours there; but the ice-hockey which the ordinary winter visitor will be apt to join in will probably be of the most elementary and unscientific kind indulged in, when the skating day is drawing to a close, by picked-up sides. As will be readily understood, the ice over which a hockey match has been played is perfectly useless for skaters any more that day until it has been swept, scraped, and sprinkled or flooded; and in consequence, at all Swiss resorts, with the exception of St. Moritz, where there is a rink that has been made for the hockey-player, or when an important match is being played, this sport is supplementary to such others as I have spoken of. Nobody, that is, plays hockey and nothing else, since he cannot play hockey at all till the greedy skaters have finished with the ice.',
#   'metadata': {'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': '67d58ab3aae6e41e9ce429dc4cbe5501'}},
#  {'type': 'NarrativeText',
#   'element_id': '2ba6b9d84d77ce436f247537bd1546ef',
#   'text': 'And in most places hockey is not taken very seriously: it is a charming and heat-producing scramble to take part in when the out-door day is drawing to a close and the chill of the evening beginning to set in; there is a vast quantity of falling down in its componence and not very many goals, and a general ignorance about rules. But since a game, especially such a wholly admirable and delightful game as ice-hockey, may just as well be played on the lines laid down for its conduct as not, I append at the end of this short section a copy of the latest edition of the rules as issued by Prince’s Club, London.',
#   'metadata': {'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': '67d58ab3aae6e41e9ce429dc4cbe5501'}},
#  {'type': 'NarrativeText',
#   'element_id': '1f14432f4482db83e2fa6b28bb90ea4e',
#   'text': 'For the rest, everybody knows the “sort of thing” hockey is, and quite rightly supposes that ice-hockey is the same “sort of thing” played on a field of ice by performers shod in skates. As is natural, the practice and ability which enable a man to play ordinary hockey with moderate success are a large factor in his success when he woos the more elusive sister-sport; another factor, and one which is not sufficiently appreciated, is the strength of his skating. It is not enough to be able to run very swiftly on the skates: no one is an ice-hockey player of the lowest grade who cannot turn quickly to right or left, start quickly, and above all, stop quickly. However swift a player may be, he is practically useless to his side unless he can, with moderate suddenness, check his headlong career, turn quickly, and when the time comes again start quickly.',
#   'metadata': {'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': '67d58ab3aae6e41e9ce429dc4cbe5501'}},
#  {'type': 'NarrativeText',
#   'element_id': 'd43151deddba64dbaf7dc9d1adf66202',
#   'text': 'I have often been asked whether ice-hockey is “bad” for skating. Most emphatically it is not: on the other hand, it is extremely good for most skaters, since it gives them strength of ankle and accustoms them to move at a high speed. Strength, as we have seen before, is not the prime need of a skater, but balance: strength, however, is a most useful adjunct. But though hockey is good for the skater, he will certainly find that he will not skate well or accurately immediately after playing hockey, any more than he will skate well the moment he has taken off his skis. But the feeling that to play hockey unfits the skater for that which he may regard as his more artistic job, is, as far as can be seen, unfounded.',
#   'metadata': {'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': '67d58ab3aae6e41e9ce429dc4cbe5501'}},
#  {'type': 'NarrativeText',
#   'element_id': '0791aa8ea15b2daad16d8135fa23b403',
#   'text': 'But such is not the aspect of the game that will strike the observer who watches the usual pick-up or inter-hotel match on the rink, which generally begins as soon as skaters hear the curfew of the tea-bell. Here will be found the individualist who, sooner than pass when he has once got the puck, would infinitely prefer to fall and be trampled on; and you will see him, while still sitting on the ice, hacking wildly at the beloved india-rubber, in flat contravention of the rule. Common, too, are the “non-stops” (like Wimbledon trains) who, once having got up speed, are practically brakeless. Indeed, it was in connection with non-stops that the present writer saw the most ludicrously comic incident that it has ever been his good luck to encounter in these winter places, where so many funny things happen. And it was in this manner. A round dozen of these delightful nonstops had made up a hockey match. The rink where they played bounded on three sides by snow-banks; on the fourth, at the edge of which was one of their goals, an extremely steep descent (caused by the levelling up of the ground to make the rink), about 15 feet in height, plunged into the snow-covered field below. It was a very cold afternoon, and (so rightly) the two gentlemen who were deputed to keep goal preferred to plunge into the fray and go for the puck whenever they could catch sight of it. In general, there were some four or five out of the twelve players on their feet simultaneously: the rest were momentarily prone. All this was delightful enough, but I had no conception how funny they were all going to be.',
#   'metadata': {'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': '67d58ab3aae6e41e9ce429dc4cbe5501'}},
#  {'type': 'NarrativeText',
#   'element_id': 'c70c45a83232a47976e02d29df3a6529',
#   'text': '(iii) Opposite Wengen (or rather a little further south) and on the other side of the Lauterbrunnen valley, stands Mürren, at an altitude of 5500 feet, 1000 feet higher than Wengen. It has only been opened lately as a Swiss winter resort, and is blest with many natural and artificial excellences. A curling-rink adjoins the large skating-rink, and the ice, made in the “Boss method,” is wonderfully good. Here the Continental and English skaters may be seen side by side, and the two schools flourish, as is reasonable, without the smallest friction. For the skier there are any amount of expeditions, and the very large extent and variety of the northern slopes above Mürren, combined with its height, render it safe even in bad winters from continued thaws: it owns also (for the more daring) one of the best jumps in Switzerland. This year (1912) the railway has been continued to the top of the Allmendhubel, from where a bob-sleigh run will start, and will give skiers a lift to the upper snows. The inter-university ice-hockey match has for the last three years been played here. Apart from its excellent faculties for sport, it is a place of unrivalled natural beauty ... but perhaps you have heard enough about the view. It is excellently shielded from the northerly winds, and its height, as in the case of Davos and St. Moritz, gives it a reasonable chance of immunity from thaw.',
#   'metadata': {'languages': ['eng'],
#    'filename': 'winter-sports.epub',
#    'filetype': 'application/epub',
#    'parent_id': 'abf6c56da07865fca96ade750885a7b7'}}]

# %%
# Mapping Chapters to their IDs as parsed by the ETL.

chapters = [
    "THE SUN-SEEKER",
    "RINKS AND SKATERS",
    "TEES AND CRAMPITS",
    "ICE-HOCKEY",
    "SKI-ING",
    "NOTES ON WINTER RESORTS",
    "FOR PARENTS AND GUARDIANS",
]

chapter_ids = {}
for element in resp.elements:
    for chapter in chapters:
        if chapter in element["text"] and element["type"] == "Title":
            chapter_ids[element["element_id"]] = chapter
            break

# %%
chapter_ids
# Out:
# {'65af5da00154a2f526b43177bbad3189': 'THE SUN-SEEKER',
#  '4e3f02ce1525ca1a197b5d5e9cd1953d': 'RINKS AND SKATERS',
#  'c2f9b5a30cb07d9adaf5f390dc8e7564': 'TEES AND CRAMPITS',
#  '67d58ab3aae6e41e9ce429dc4cbe5501': 'ICE-HOCKEY',
#  'ea7faf4689009a3b72bf19dc10f29037': 'SKI-ING',
#  'ea3feb77c48592d21a05386e68fde88e': 'NOTES ON WINTER RESORTS',
#  '56c4ba79d33a505bb9b4480d7a5a4ce7': 'FOR PARENTS AND GUARDIANS'}

# %%
# Configure a function that returns a chapter ID given a chapter name.
chapter_to_id = {v: k for k, v in chapter_ids.items()}

#Fetch a paragraph from the chapter ice Hockey.
[x for x in resp.elements if x["metadata"].get("parent_id") == chapter_to_id["ICE-HOCKEY"]][0]
# Out:
# {'type': 'NarrativeText',
#  'element_id': '24a39efc765a60db62dd23405133a957',
#  'text': 'Many of the Swiss winter-resorts can put into the field a very strong ice-hockey team, and fine teams from other countries often make winter tours there; but the ice-hockey which the ordinary winter visitor will be apt to join in will probably be of the most elementary and unscientific kind indulged in, when the skating day is drawing to a close, by picked-up sides. As will be readily understood, the ice over which a hockey match has been played is perfectly useless for skaters any more that day until it has been swept, scraped, and sprinkled or flooded; and in consequence, at all Swiss resorts, with the exception of St. Moritz, where there is a rink that has been made for the hockey-player, or when an important match is being played, this sport is supplementary to such others as I have spoken of. Nobody, that is, plays hockey and nothing else, since he cannot play hockey at all till the greedy skaters have finished with the ice.',
#  'metadata': {'languages': ['eng'],
#   'filename': 'winter-sports.epub',
#   'filetype': 'application/epub',
#   'parent_id': '67d58ab3aae6e41e9ce429dc4cbe5501'}}

# %% [markdown]
# ### Creating a vector database and filling it with the parsed information from our EPUB
#
# Below we will create a vector database using Chromadb, we'll first create the db as a collection, and then fill it with the data and metadata we've extracted.

# %%
client = chromadb.PersistentClient(path="./chroma_tmp", settings=chromadb.Settings(allow_reset=True))
client.reset()
# Out:
# True

# %%
collection = client.create_collection(
    name="winter_sports",
    metadata={"hnsw:space": "cosine"}
)

# %%
for element in resp.elements:
    parent_id = element["metadata"].get("parent_id")
    chapter = chapter_ids.get(parent_id, "")
    collection.add(
        documents=[element["text"]],
        ids=[element["element_id"]],
        metadatas=[{"chapter": chapter}]
    )
# Out:
# C:\Users\LENOVO\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|██████████| 79.3M/79.3M [00:07<00:00, 11.0MiB/s]

# %% [markdown]
# Here we are using the peek function to get a random sample of what we have within our freshly created vector database.

# %%
results = collection.peek()
print(results["documents"])
# Out:
# ['The Project Gutenberg eBook of Winter Sports in Switzerland, by E. F. Benson', 'This ebook is for the use of anyone anywhere in the United States and most other parts of the world at no cost and with almost no restrictions whatsoever. You may copy it, give it away or re-use it under the terms of the Project Gutenberg License included with this ebook or online at www.gutenberg.org. If you are not located in the United States, you’ll have to check the laws of the country where you are located before using this eBook.', 'Title: Winter Sports in Switzerland', 'Author: E. F. Benson', 'Illustrator: C. Fleming Williams', 'Photographer: Mrs. Aubrey Le Blond', 'Release date: August 23, 2019 [EBook #60153] Most recently updated: January 30, 2020', 'Language: English', 'Credits: Produced by Chuck Greif and the Online Distributed Proofreading Team at http://www.pgdp.net (This file was produced from images available at The Internet Archive)', '*** START OF THE PROJECT GUTENBERG EBOOK WINTER SPORTS IN SWITZERLAND ***']

# %% [markdown]
# Here we are querying the database with a specific question, the hybrid search intervenes in the where clause, as we've specified the context that the search will be limited to. The number of results has also been limited to 2 to return only the 2 highest matches.

# %%
result = collection.query(
    query_texts=["What's by the fireside?"],
    n_results=2,
    where={"chapter": "THE SUN-SEEKER"},
)
print(json.dumps(result, indent=2))

# %% [markdown]
# ### Chunking Content
#
# In this section, we'll be covering how to chunk content using the unstructured library

# %%
# Chunking by Title, while maintaining a minimum of 100 characters and a maximum of 3000 characters per chunk.

elements = dict_to_elements(resp.elements)
chunks = chunk_by_title(
    elements,
    combine_text_under_n_chars=100,
    max_characters=3000,
)

len(elements)

JSON(json.dumps(chunks[0].to_dict(), indent=2))

# %%
len(chunks)
# Out:
# 165

# %% [markdown]
# ## Preprocessing PDFs & Images
#
# This section covers in more detail, the preprocessing of PDFs and images with the Unstructured Open source library and platform API.

# %% [markdown]
# ### Main Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared
from unstructured_client.models.errors import SDKError

from unstructured.partition.html import partition_html
from unstructured.partition.pdf import partition_pdf

from unstructured.staging.base import dict_to_elements

# %% [markdown]
# ### Process the document as HTML, to use as a benchmark for our PDF processing

# %%
filename = "./example_files/el_nino.html"
html_elements = partition_html(filename=filename)

for element in html_elements[:10]:
    print(f"{element.category.upper()}: {element.text}")
# Out:
# UNCATEGORIZEDTEXT: CNN 1/30/2024
# TITLE: A potent pair of atmospheric rivers will drench California as El Niño makes its first mark on winter
# UNCATEGORIZEDTEXT: By Mary Gilbert, CNN Meteorologist
# UNCATEGORIZEDTEXT: Updated: 3:49 PM EST, Tue January 30, 2024
# UNCATEGORIZEDTEXT: Source: CNN
# NARRATIVETEXT: A potent pair of atmospheric river-fueled storms are about to unleash a windy and incredibly wet week in California in what is the first clear sign of the influence El Niño was expected to have on the state this winter.
# NARRATIVETEXT: The soaking storms will raise the flood threat across much of California into next week, but it appears the wet pattern is likely to continue well into February as a more typical El Niño pattern kicks into gear.
# NARRATIVETEXT: El Niño – a natural phenomenon in the tropical Pacific that influences weather around the globe – causes changes in the jet stream that can point storms directly at California. Storms can also tap into an extra-potent supply of moisture from the tropics called an atmospheric river.
# NARRATIVETEXT: El Niño hasn’t materialized many atmospheric rivers for California so far this winter, with most hitting the Pacific Northwest.
# NARRATIVETEXT: But all that is set to change this week.

# %% [markdown]
# ### Processing with DLD (Document Layout Detection)

# %% [markdown]
# First using partition_pdf for a quick overview

# %%
filename = "./example_files/el_nino.pdf"
pdf_elements = partition_pdf(filename=filename, strategy="fast")

for element in pdf_elements[:10]:
    print(f"{element.category.upper()}: {element.text}")
# Out:
# INFO: pikepdf C++ to Python logger bridge initialized
# HEADER: 1/30/24, 5:11 PM
# HEADER: Pineapple express: California to get drenched by back-to-back storms fueling a serious ﬂood threat | CNN
# HEADER: CNN 1/30/2024
# NARRATIVETEXT: A potent pair of atmospheric rivers will drench California as El Niño makes its ﬁrst mark on winter
# TITLE: By Mary Gilbert, CNN Meteorologist
# TITLE: Updated: 3:49 PM EST, Tue January 30, 2024
# TITLE: Source: CNN
# NARRATIVETEXT: A potent pair of atmospheric river-fueled storms are about to unleash a windy and incredibly wet week in California in what is the ﬁrst clear sign of the inﬂuence El Niño was expected to have on the state this winter.
# NARRATIVETEXT: The soaking storms will raise the ﬂood threat across much of California into next week, but it appears the wet pattern is likely to continue well into February as a more typical El Niño pattern kicks into gear.
# NARRATIVETEXT: El Niño – a natural phenomenon in the tropical Paciﬁc that inﬂuences weather around the globe – causes changes in the jet stream that can point storms directly at California. Storms can also tap into an extra-potent supply of moisture from the tropics called an atmospheric river.

# %% [markdown]
# Using DLD with YOLOX as the object detection model. We have no need for OCR here because of the document we're using so it's a single model call.

# %%
with open(filename, "rb") as f:
    files=shared.Files(
        content=f.read(),
        file_name=filename,
    )

params = shared.PartitionParameters(
    files=files,
    strategy="hi_res",
    hi_res_model_name="yolox",
)

req=operations.PartitionRequest(partition_parameters=params)

try:
    resp = s.general.partition(request=req)
    dld_elements = dict_to_elements(resp.elements)
except SDKError as e:
    print(e)


for element in dld_elements[:10]:
    print(f"{element.category.upper()}: {element.text}")
# Out:
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# HEADER: 1/30/24, 5:11 PM
# HEADER: CNN 1/30/2024
# HEADER: Pineapple express: California to get drenched by back-to-back storms fueling a serious ﬂood threat | CNN
# TITLE: A potent pair of atmospheric rivers will drench California as El Niño makes its ﬁrst mark on winter
# NARRATIVETEXT: By Mary Gilbert, CNN Meteorologist
# NARRATIVETEXT: Updated: 3:49 PM EST, Tue January 30, 2024
# NARRATIVETEXT: Source: CNN
# NARRATIVETEXT: A potent pair of atmospheric river-fueled storms are about to unleash a windy and incredibly wet week in California in what is the ﬁrst clear sign of the inﬂuence El Niño was expected to have on the state this winter.
# NARRATIVETEXT: The soaking storms will raise the ﬂood threat across much of California into next week, but it appears the wet pattern is likely to continue well into February as a more typical El Niño pattern kicks into gear.
# NARRATIVETEXT: El Niño – a natural phenomenon in the tropical Paciﬁc that inﬂuences weather around the globe – causes changes in the jet stream that can point storms directly at California. Storms can also tap into an extra-potent supply of moisture from the tropics called an atmospheric river.

# %% [markdown]
# Now let's compare the DLD output to our HTML output and see if it was well done on the PDF side of things

# %%
import collections

len(html_elements)

html_categories = [el.category for el in html_elements]
collections.Counter(html_categories).most_common()
# Out:
# [('NarrativeText', 23), ('UncategorizedText', 6), ('Title', 2)]

# %%
len(dld_elements)

dld_categories = [el.category for el in dld_elements]
collections.Counter(dld_categories).most_common()
# Out:
# [('NarrativeText', 28), ('Header', 6), ('Title', 4), ('Footer', 1)]

# %% [markdown]
# ## Extracting Tables
#
# In this part we'll cover table extraction using the Unstructured Platform API.

# %% [markdown]
# ### Main imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared,operations
from unstructured_client.models.errors import SDKError

from unstructured.staging.base import dict_to_elements


_ = load_dotenv(find_dotenv())

import os

DLAI_API_KEY = os.getenv("U_API_KEY")
DLAI_API_URL = os.getenv("U_API_URL")

s = UnstructuredClient(
    api_key_auth=DLAI_API_KEY,
    server_url=DLAI_API_URL,
)

# %% [markdown]
# ### Extracting tables from a PDF table

# %%
filename = "./example_files/embedded-images-tables.pdf"

with open(filename, "rb") as f:
    files=shared.Files(
        content=f.read(),
        file_name=filename,
    )

params = shared.PartitionParameters(
    files=files,
    strategy="hi_res",
    hi_res_model_name="yolox",
    skip_infer_table_types=[],
    pdf_infer_table_structure=True,
)

req=operations.PartitionRequest(partition_parameters=params)

try:
    resp = s.general.partition(request=req)
    elements = dict_to_elements(resp.elements)
except SDKError as e:
    print(e)
# Out:
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"

# %%
#Extracting only tables from the elements.
tables = [el for el in elements if el.category == "Table"]
tables[0].text
# Out:
# 'Inhibitor Polarization Corrosion be (V/dec) ba (V/dec) Ecorr (V) icorr (Acm?) concentration (g) resistance (Q) rate (mmj/year) 0.0335 0.0409 —0.9393 0.0003 24.0910 2.8163 1.9460 0.0596 .8276 0.0002 121.440 1.5054 0.0163 0.2369 .8825 0.0001 42121 0.9476 NO 0233 0.0540 —0.8027 5.39E-05 373.180 0.4318 0.1240 0.0556 .5896 5.46E-05 305.650 0.3772 = 5 0.0382 0.0086 .5356 1.24E-05 246.080 0.0919'

# %%
#Converting the table output to HTML

table_html = tables[0].metadata.text_as_html

from io import StringIO 
from lxml import etree

parser = etree.XMLParser(remove_blank_text=True)
file_obj = StringIO(table_html)
tree = etree.parse(file_obj, parser)
print(etree.tostring(tree, pretty_print=True).decode())
# Out:
# <table>
#   <thead>
#     <tr>
#       <th>Inhibitor concentration (g)</th>
#       <th>be (V/dec)</th>
#       <th>ba (V/dec)</th>
#       <th>Ecorr (V)</th>
#       <th>icorr (Acm?)</th>
#       <th>Polarization resistance (Q)</th>
#       <th>Corrosion rate (mmj/year)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td/>
#       <td>0.0335</td>
#       <td>0.0409</td>
#       <td>&#8212;0.9393</td>
#       <td>0.0003</td>
#       <td>24.0910</td>
#       <td>2.8163</td>
#     </tr>
#     <tr>
#       <td>NO</td>
#       <td>1.9460</td>
#       <td>0.0596</td>
#       <td>&#8212;0.8276</td>
#       <td>0.0002</td>
#       <td>121.440</td>
#       <td>1.5054</td>
#     </tr>
#     <tr>
#       <td/>
#       <td>0.0163</td>
#       <td>0.2369</td>
#       <td>&#8212;0.8825</td>
#       <td>0.0001</td>
#       <td>42121</td>
#       <td>0.9476</td>
#     </tr>
#     <tr>
#       <td/>
#       <td>0233</td>
#       <td>0.0540</td>
#       <td>&#8212;0.8027</td>
#       <td>5.39E-05</td>
#       <td>373.180</td>
#       <td>0.4318</td>
#     </tr>
#     <tr>
#       <td/>
#       <td>0.1240</td>
#       <td>0.0556</td>
#       <td>&#8212;0.5896</td>
#       <td>5.46E-05</td>
#       <td>305.650</td>
#       <td>0.3772</td>
#     </tr>
#     <tr>
#       <td>= 5</td>
#       <td>0.0382</td>
#       <td>0.0086</td>
#       <td>&#8212;0.5356</td>
#       <td>1.24E-05</td>
#       <td>246.080</td>
#       <td>0.0919</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Display the table
from IPython.core.display import HTML
HTML(table_html)
# Out:
# <table><thead><tr><th>Inhibitor concentration (g)</th><th>be (V/dec)</th><th>ba (V/dec)</th><th>Ecorr (V)</th><th>icorr (Acm?)</th><th>Polarization resistance (Q)</th><th>Corrosion rate (mmj/year)</th></tr></thead><tbody><tr><td></td><td>0.0335</td><td>0.0409</td><td>—0.9393</td><td>0.0003</td><td>24.0910</td><td>2.8163</td></tr><tr><td>NO</td><td>1.9460</td><td>0.0596</td><td>—0.8276</td><td>0.0002</td><td>121.440</td><td>1.5054</td></tr><tr><td></td><td>0.0163</td><td>0.2369</td><td>—0.8825</td><td>0.0001</td><td>42121</td><td>0.9476</td></tr><tr><td></td><td>0233</td><td>0.0540</td><td>—0.8027</td><td>5.39E-05</td><td>373.180</td><td>0.4318</td></tr><tr><td></td><td>0.1240</td><td>0.0556</td><td>—0.5896</td><td>5.46E-05</td><td>305.650</td><td>0.3772</td></tr><tr><td>= 5</td><td>0.0382</td><td>0.0086</td><td>—0.5356</td><td>1.24E-05</td><td>246.080</td><td>0.0919</td></tr></tbody></table>

# %% [markdown]
# ### Utilizing Tables in RAG Applications (Example with Langchain)

# %%
from langchain_openai import ChatOpenAI
from langchain_core.documents import Document
from langchain.chains.summarize import load_summarize_chain

# %%
llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo-1106")
chain = load_summarize_chain(llm, chain_type="stuff")
chain.invoke([Document(page_content=table_html)])
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {'input_documents': [Document(metadata={}, page_content='<table><thead><tr><th>Inhibitor concentration (g)</th><th>be (V/dec)</th><th>ba (V/dec)</th><th>Ecorr (V)</th><th>icorr (Acm?)</th><th>Polarization resistance (Q)</th><th>Corrosion rate (mmj/year)</th></tr></thead><tbody><tr><td></td><td>0.0335</td><td>0.0409</td><td>—0.9393</td><td>0.0003</td><td>24.0910</td><td>2.8163</td></tr><tr><td>NO</td><td>1.9460</td><td>0.0596</td><td>—0.8276</td><td>0.0002</td><td>121.440</td><td>1.5054</td></tr><tr><td></td><td>0.0163</td><td>0.2369</td><td>—0.8825</td><td>0.0001</td><td>42121</td><td>0.9476</td></tr><tr><td></td><td>0233</td><td>0.0540</td><td>—0.8027</td><td>5.39E-05</td><td>373.180</td><td>0.4318</td></tr><tr><td></td><td>0.1240</td><td>0.0556</td><td>—0.5896</td><td>5.46E-05</td><td>305.650</td><td>0.3772</td></tr><tr><td>= 5</td><td>0.0382</td><td>0.0086</td><td>—0.5356</td><td>1.24E-05</td><td>246.080</td><td>0.0919</td></tr></tbody></table>')],
#  'output_text': 'The table provides data on the corrosion rate and polarization resistance of different inhibitor concentrations. The data includes values for be (V/dec), ba (V/dec), Ecorr (V), icorr (Acm?), Polarization resistance (Q), and Corrosion rate (mmj/year). The inhibitor concentrations range from 0 to 5, and the corresponding corrosion rates and polarization resistances are provided for each concentration.'}

# %% [markdown]
# ## Building our own RAG Bot
#
# In this section, we'll be utilizing all the techniques we've learned from the previous sections to build our own RAG Bot that will work based on the unstructured data repository that we have for it.

# %% [markdown]
# ### Main Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

from unstructured_client import UnstructuredClient
from unstructured_client.models import shared,operations
from unstructured_client.models.errors import SDKError

from unstructured.chunking.title import chunk_by_title
from unstructured.partition.md import partition_md
from unstructured.partition.pptx import partition_pptx
from unstructured.staging.base import dict_to_elements

from dotenv import load_dotenv, find_dotenv


import chromadb

_ = load_dotenv(find_dotenv())

import os

DLAI_API_KEY = os.getenv("U_API_KEY")
DLAI_API_URL = os.getenv("U_API_URL")

s = UnstructuredClient(
    api_key_auth=DLAI_API_KEY,
    server_url=DLAI_API_URL,
)

# %% [markdown]
# ### Reading our context files

# %% [markdown]
# Below, we'll read the PDF file using the unstructured API and preprocess it for insertion in our Chromadb vector Database.

# %%
# Parsing the pdf file using the unstructured API.

filename = "./rag_context/donut_paper.pdf"

with open(filename, "rb") as f:
    files=shared.Files(
        content=f.read(),
        file_name=filename,
    )

params = shared.PartitionParameters(
    files=files,
    strategy="hi_res", #Document Layout Detection
    hi_res_model_name="yolox",
    pdf_infer_table_structure=True,
    skip_infer_table_types=[],
)

req=operations.PartitionRequest(partition_parameters=params)

try:
    resp = s.general.partition(request=req)
    pdf_elements = dict_to_elements(resp.elements)
except SDKError as e:
    print(e)
# Out:
# INFO: HTTP Request: GET https://api.unstructuredapp.io/general/docs "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructuredapp.io/general/v0/general "HTTP/1.1 200 OK"

# %%
#Extracting tables from the parsed PDF elements

tables = [el for el in pdf_elements if el.category == "Table"]
table_html = tables[0].metadata.text_as_html

# %%
#Visualize the tables

from io import StringIO 
from lxml import etree

parser = etree.XMLParser(remove_blank_text=True)
file_obj = StringIO(table_html)
tree = etree.parse(file_obj, parser)
print(etree.tostring(tree, pretty_print=True).decode())
# Out:
# <table>
#   <tbody/>
# </table>

# %%
#Get reference titles from the parsed PDF so we remove them later.
reference_title = [
    el for el in pdf_elements
    if el.text == "References"
    and el.category == "Title"
][0]

reference_title.to_dict()
references_id = reference_title.id

for element in pdf_elements:
    if element.metadata.parent_id == references_id:
        print(element)
        break

pdf_elements = [el for el in pdf_elements if el.metadata.parent_id != references_id]
# Out:
# 1. Afzal, M.Z., Capobianco, S., Malik, M.I., Marinai, S., Breuel, T.M., Dengel, A., Liwicki, M.: Deepdocclassifier: Document classification with deep convolutional neural network. In: 2015 13th International Conference on Document Analysis and Recognition (ICDAR). pp. 1111–1115 (2015). https://doi.org/10.1109/ICDAR.2015.7333933 1, 4, 14

# %%
# Remove PDF Headers so it doesn't impact the file.

headers = [el for el in pdf_elements if el.category == "Header"]
headers[1].to_dict()
pdf_elements = [el for el in pdf_elements if el.category != "Header"]

# %% [markdown]
# PowerPoint file Preprocessing

# %%
filename = "./rag_context/donut_slide.pptx"
pptx_elements = partition_pptx(filename=filename)

# %% [markdown]
# Markdown file preprocessing

# %%
filename = "./rag_context/donut_readme.md"
md_elements = partition_md(filename=filename)

# %% [markdown]
# ### Loading the documents into the Vector DB
#
# Below, we will load the documents into our vector DB. First we will chunk them. then we will create embeddings for them and load them into the database alongside the embeddings.

# %%
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores.utils import filter_complex_metadata

# %%
#Chunking the elements by title.
elements = chunk_by_title(pdf_elements + pptx_elements + md_elements)

documents = []
for element in elements:
    metadata = element.metadata.to_dict()
    del metadata["languages"]
    metadata["source"] = metadata["filename"]
    documents.append(Document(page_content=element.text, metadata=metadata))

embeddings = OpenAIEmbeddings()
vectorstore = Chroma.from_documents(filter_complex_metadata(documents), embeddings)
retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}
)
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %% [markdown]
# ### Preparing the RAG Bot

# %%
from langchain.prompts.prompt import PromptTemplate
from langchain_openai import OpenAI
from langchain.chains import ConversationalRetrievalChain, LLMChain
from langchain.chains.qa_with_sources import load_qa_with_sources_chain

template = """You are an AI assistant for answering questions about the Donut document understanding model.
You are given the following extracted parts of a long document and a question. Provide a conversational answer.
If you don't know the answer, just say "Hmm, I'm not sure." Don't try to make up an answer.
If the question is not about Donut, politely inform them that you are tuned to only answer questions about Donut.
Question: {question}
=========
{context}
=========
Answer in Markdown:"""
prompt = PromptTemplate(template=template, input_variables=["question", "context"])

# %%
llm = OpenAI(temperature=0)

doc_chain = load_qa_with_sources_chain(llm, chain_type="map_reduce")
question_generator_chain = LLMChain(llm=llm, prompt=prompt)
qa_chain = ConversationalRetrievalChain(
    retriever=retriever,
    question_generator=question_generator_chain,
    combine_docs_chain=doc_chain,
)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_26204\3323193037.py:3: LangChainDeprecationWarning: This function is deprecated. Refer to this guide on retrieval and question answering with sources: https://python.langchain.com/docs/how_to/qa_sources/
# See also the following migration guides for replacements based on `chain_type`:
# stuff: https://python.langchain.com/docs/versions/migrating_chains/stuff_docs_chain
# map_reduce: https://python.langchain.com/docs/versions/migrating_chains/map_reduce_chain
# refine: https://python.langchain.com/docs/versions/migrating_chains/refine_chain
# map_rerank: https://python.langchain.com/docs/versions/migrating_chains/map_rerank_docs_chain
#
#   doc_chain = load_qa_with_sources_chain(llm, chain_type="map_reduce")
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_26204\3323193037.py:4: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   question_generator_chain = LLMChain(llm=llm, prompt=prompt)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_26204\3323193037.py:5: LangChainDeprecationWarning: The class `ConversationalRetrievalChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~create_history_aware_retriever together with create_retrieval_chain (see example in docstring)` instead.
#   qa_chain = ConversationalRetrievalChain(

# %%
qa_chain.invoke({
    "question": "How does Donut compare to other document understanding models?",
    "chat_history": []
})["answer"]
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/completions "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/completions "HTTP/1.1 200 OK"
# ' Donut is a state-of-the-art document understanding model that does not require OCR and can be trained in an end-to-end fashion. It uses a simple architecture consisting of a visual encoder and textual decoder. \nSOURCES: donut_readme.md, donut_paper.pdf, donut_slide.pptx'

# %%
filter_retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 1, "filter": {"source": "donut_readme.md"}}
)

# %%
filter_chain = ConversationalRetrievalChain(
    retriever=filter_retriever,
    question_generator=question_generator_chain,
    combine_docs_chain=doc_chain,
)

filter_chain.invoke({
    "question": "How do I classify documents with DONUT?",
    "chat_history": [],
    "filter": filter,
})["answer"]
# Out:
# INFO: HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/completions "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.openai.com/v1/completions "HTTP/1.1 200 OK"
# ' DONUT can classify documents through visual document classification or information extraction. \nSOURCES: donut_readme.md'

# %% [markdown]
# # And that's IT. I hope you learned as much as I did !
#
# Peace, Zack
